# %% [markdown]
# # Beten nach Daten: statistiche Übersichten betr. Datum, Format und Entstehungsort

# %% [markdown]
# <a href="https://colab.research.google.com/github/oriflamms/LivreQuanti2023/blob/main/DataModelling/Zeit-Raum-Dimensionen-Deutschland.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Environment

# %%
import os, pandas as pd, numpy as np
from urllib.request import urlopen

from scipy.stats import chi2_contingency
print(os.getcwd())
# os.chdir('Seafile/Seafile/HORAE-Daten-Übung')
# print(os.getcwd())
# Set the maximum number of rows and columns to display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\stutzmann\Github\LivreQuanti2023\DataModelling

# %% [markdown]
# # Data (capta)

# %% [markdown]
# ## Load data and check contents

# %%
'''
file_url_1 = 'https://github.com/oriflamms/LivreQuanti2023/raw/main/DataModelling/Export_stutzmann_horae_t53_Manuscript_rich_20231109.xlsx'
file_url_2 = 'https://raw.githubusercontent.com/oriflamms/LivreQuanti2023/main/DataModelling/t53_Manuscript_Country.csv'
file_content_1 = urlopen(file_url_1).read().decode('utf-8')
file_content_2 = urlopen(file_url_2).read().decode('utf-8')
'''
# Out:
# "\nfile_url_1 = 'https://github.com/oriflamms/LivreQuanti2023/raw/main/DataModelling/Export_stutzmann_horae_t53_Manuscript_rich_20231109.xlsx'\nfile_url_2 = 'https://raw.githubusercontent.com/oriflamms/LivreQuanti2023/main/DataModelling/t53_Manuscript_Country.csv'\nfile_content_1 = urlopen(file_url_1).read().decode('utf-8')\nfile_content_2 = urlopen(file_url_2).read().decode('utf-8')\n"

# %%
#df = pd.read_excel('./Export_stutzmann_horae_t53_numformat.xlsx', sheet_name='Capta')
df = pd.read_excel('./Export_stutzmann_horae_t53_Manuscript_rich_20231109.xlsx', sheet_name='Tabelle2')

# %%
print(df.shape)
print(list(df.columns))
df.head()
# Out:
# (8916, 33)
# ['Manuscript H-ID', 'repository_key (Organisation) H-ID', 'repository_key (Organisation) Record Title', 'idno', 'altIdentifier', 'idMedium', 'msItem H-ID', 'rec_Title_2', 'Work H-ID', 'Work Record Title', 'number of volume', 'support', 'extent', 'leaf dimensions : height (mm)', 'leaf dimensions : width (mm)', 'justification : height (mm)', 'justification : width (mm)', 'columns', 'writtenLines', 'script type', 'formality', 'origDate', 'origDate : from', 'origDate : to', 'origDate : proposed date', 'origPlace (relationship marker) H-ID', 'origPlace (relationship marker) Record Title', 'origPlace : proposed origin', 'iiif manifest', 'bibl H-ID', 'bibl Record Title', 'external link (Web site / page) H-ID', 'external link (Web site / page) Record Title']
#    Manuscript H-ID  repository_key (Organisation) H-ID  \
# 0              433                              739889
# 1           734419                              740297
# 2             6513                              740138
# 3             6494                              740138
# 4             6456                              740138
#
#           repository_key (Organisation) Record Title         idno  \
# 0  Montréal, McGill University Library (Organisat...          101
# 1  Maastricht, Regionaal Historisch Centrum Limbu...       ms. 48
# 2  Cambridge (MA), Harvard University, Houghton L...  MS Typ 0464
# 3  Cambridge (MA), Harvard University, Houghton L...  MS Typ 1000
# 4  Cambridge (MA), Harvard University, Houghton L...   MS Lat 017
#
#   altIdentifier     idMedium msItem H-ID  \
# 0           NaN  100086833.0      737250
# 1           NaN          NaN      735336
# 2           NaN          NaN      715768
# 3           NaN          NaN      715765
# 4           NaN          NaN      715762
#
#                                          rec_Title_2 Work H-ID  \
# 0  Montréal, McGill University Library, 101 : Hou...     75966
# 1  Maastricht, Regionaal Historisch Centrum Limbu...     75966
# 2  Cambridge (MA), Harvard University, Houghton L...     75966
# 3  Cambridge (MA), Harvard University, Houghton L...     75966
# 4  Cambridge (MA), Harvard University, Houghton L...     75966
#
#                     Work Record Title number of volume    support  \
# 0  Hours of the Virgin | L1 | Section              NaN  parchment
# 1  Hours of the Virgin | L1 | Section              NaN  parchment
# 2  Hours of the Virgin | L1 | Section              NaN  parchment
# 3  Hours of the Virgin | L1 | Section              NaN  parchment
# 4  Hours of the Virgin | L1 | Section              NaN  parchment
#
#                                               extent  \
# 0                              053 ff. (CCLL)|53 ff.
# 1                         105 ff. (paginated: 1-204)
# 2                             147 ff. (CCLL)|ff. 147
# 3  ff.162 ( numbered ff. 171, lacking ff. 144, 14...
# 4                                     141 ff. (CCLL)
#
#   leaf dimensions : height (mm) leaf dimensions : width (mm)  \
# 0                           NaN                          NaN
# 1                           177                          131
# 2                           116                           88
# 3                            83                           57
# 4                           200                          132
#
#   justification : height (mm) justification : width (mm)  columns  \
# 0                          98                         60      1.0
# 1                         101                         70      1.0
# 2                          64                         45      1.0
# 3                          54                         36      NaN
# 4                         NaN                        NaN      1.0
#
#    writtenLines   script type formality origDate origDate : from  \
# 0           NaN           NaN       NaN      NaN       1470|1450
# 1          17.0     Textualis       NaN      NaN            1451
# 2           NaN       Cursiva       NaN      NaN            1480
# 3           NaN  Humanistique       NaN      NaN            1501
# 4           NaN       Hybrida       NaN      NaN            1476
#
#   origDate : to    origDate : proposed date  \
# 0     1470|1480                         NaN
# 1          1475  third quarter 15th century
# 2          1500                  c. 1475-80
# 3          1550                  c. 1500-10
# 4          1500                         NaN
#
#   origPlace (relationship marker) H-ID  \
# 0                                37509
# 1                                37669
# 2                                38142
# 3                                38068
# 4                                37638
#
#   origPlace (relationship marker) Record Title origPlace : proposed origin  \
# 0                               Brugge (Place)                      Bruges
# 1                              Hainaut (Place)                         NaN
# 2                              Bourges (Place)             Bourges, France
# 3                              Venezia (Place)               Venice, Italy
# 4                               France (Place)                         NaN
#
#                                        iiif manifest  \
# 0                                                NaN
# 1                                                NaN
# 2  https://iiif.lib.harvard.edu/manifests/drs:497...
# 3  https://iiif.lib.harvard.edu/manifests/drs:103...
# 4  https://iiif.lib.harvard.edu/manifests/drs:108...
#
#                                    bibl H-ID  \
# 0                              352571|737330
# 1                              736662|736663
# 2         354463|351329|741031|741991|742134
# 3                              741003|742210
# 4  356441|357556|349972|742148|742106|742300
#
#                                    bibl Record Title  \
# 0  De Ricci et Wilson 1935-1937, II, p. 2212|Dunn...
# 1     Wouters 1962, no. 95|Cat. Monnikenwerk, no. 30
# 2  1983, Cambridge (Mass), p. 34 n° 16, fig.|Bond...
# 3     Boston 2016, p. 294 n° 234|Mariani Canova 1975
# 4  Light 1995, p. 23-29, pl. 31|1983, Cambridge (...
#
#   external link (Web site / page) H-ID  \
# 0                               325568
# 1                               735403
# 2                               741340
# 3                               741328
# 4                               741221
#
#         external link (Web site / page) Record Title
# 0  McGill Digital Library, http://digital.library...
# 1  MMDC, http://www.mmdc.nl/static/site/search/de...
# 2  Digital Scriptorium, http://ds.lib.berkeley.ed...
# 3  Digital Scriptorium, http://ds.lib.berkeley.ed...
# 4  Digital Scriptorium, http://ds.lib.berkeley.ed...

# %%
print(df['leaf dimensions : height (mm)'].dtypes)
# print(df['leaf dimensions : height (mm)'].unique())
print(df['origDate'].dtypes)
# print(df['origDate'].unique())
print(df['origDate : from'].dtypes)
# print(df['origDate : from'].unique())
print(df['origDate : to'].dtypes)
# print(df['origDate : to'].unique())
# Out:
# object
# object
# object
# object

# %%
df_country = pd.read_csv('test/t53_Manuscript_Country.csv', sep=';')
df_country.head()
# Out:
#    Manuscript H-ID                              rec_Title  \
# 0                1         Admont, Stiftsbibliothek, 876b
# 1                2  Göttweig, Stiftsbibliothek, 450 (235)
# 2                3  Göttweig, Stiftsbibliothek, 452 (237)
# 3                4  Göttweig, Stiftsbibliothek, 453 (238)
# 4                5       Göttweig, Stiftsbibliothek, Sn 1
#
#   origPlace (relationship marker) H-ID Country
# 0                                  NaN     NaN
# 1                                  NaN     NaN
# 2                                  NaN     NaN
# 3                                  NaN     NaN
# 4                                  NaN     NaN

# %%
# Merge dataframes based on "Manuscript H-ID"
df = pd.merge(df, df_country[['Manuscript H-ID', 'Country']], on='Manuscript H-ID', how='left')

df.shape
# Out:
# (8916, 34)

# %%
df.head()
# Out:
#    Manuscript H-ID  repository_key (Organisation) H-ID  \
# 0              433                              739889
# 1           734419                              740297
# 2             6513                              740138
# 3             6494                              740138
# 4             6456                              740138
#
#           repository_key (Organisation) Record Title         idno  \
# 0  Montréal, McGill University Library (Organisat...          101
# 1  Maastricht, Regionaal Historisch Centrum Limbu...       ms. 48
# 2  Cambridge (MA), Harvard University, Houghton L...  MS Typ 0464
# 3  Cambridge (MA), Harvard University, Houghton L...  MS Typ 1000
# 4  Cambridge (MA), Harvard University, Houghton L...   MS Lat 017
#
#   altIdentifier     idMedium msItem H-ID  \
# 0           NaN  100086833.0      737250
# 1           NaN          NaN      735336
# 2           NaN          NaN      715768
# 3           NaN          NaN      715765
# 4           NaN          NaN      715762
#
#                                          rec_Title_2 Work H-ID  \
# 0  Montréal, McGill University Library, 101 : Hou...     75966
# 1  Maastricht, Regionaal Historisch Centrum Limbu...     75966
# 2  Cambridge (MA), Harvard University, Houghton L...     75966
# 3  Cambridge (MA), Harvard University, Houghton L...     75966
# 4  Cambridge (MA), Harvard University, Houghton L...     75966
#
#                     Work Record Title number of volume    support  \
# 0  Hours of the Virgin | L1 | Section              NaN  parchment
# 1  Hours of the Virgin | L1 | Section              NaN  parchment
# 2  Hours of the Virgin | L1 | Section              NaN  parchment
# 3  Hours of the Virgin | L1 | Section              NaN  parchment
# 4  Hours of the Virgin | L1 | Section              NaN  parchment
#
#                                               extent  \
# 0                              053 ff. (CCLL)|53 ff.
# 1                         105 ff. (paginated: 1-204)
# 2                             147 ff. (CCLL)|ff. 147
# 3  ff.162 ( numbered ff. 171, lacking ff. 144, 14...
# 4                                     141 ff. (CCLL)
#
#   leaf dimensions : height (mm) leaf dimensions : width (mm)  \
# 0                           NaN                          NaN
# 1                           177                          131
# 2                           116                           88
# 3                            83                           57
# 4                           200                          132
#
#   justification : height (mm) justification : width (mm)  columns  \
# 0                          98                         60      1.0
# 1                         101                         70      1.0
# 2                          64                         45      1.0
# 3                          54                         36      NaN
# 4                         NaN                        NaN      1.0
#
#    writtenLines   script type formality origDate origDate : from  \
# 0           NaN           NaN       NaN      NaN       1470|1450
# 1          17.0     Textualis       NaN      NaN            1451
# 2           NaN       Cursiva       NaN      NaN            1480
# 3           NaN  Humanistique       NaN      NaN            1501
# 4           NaN       Hybrida       NaN      NaN            1476
#
#   origDate : to    origDate : proposed date  \
# 0     1470|1480                         NaN
# 1          1475  third quarter 15th century
# 2          1500                  c. 1475-80
# 3          1550                  c. 1500-10
# 4          1500                         NaN
#
#   origPlace (relationship marker) H-ID  \
# 0                                37509
# 1                                37669
# 2                                38142
# 3                                38068
# 4                                37638
#
#   origPlace (relationship marker) Record Title origPlace : proposed origin  \
# 0                               Brugge (Place)                      Bruges
# 1                              Hainaut (Place)                         NaN
# 2                              Bourges (Place)             Bourges, France
# 3                              Venezia (Place)               Venice, Italy
# 4                               France (Place)                         NaN
#
#                                        iiif manifest  \
# 0                                                NaN
# 1                                                NaN
# 2  https://iiif.lib.harvard.edu/manifests/drs:497...
# 3  https://iiif.lib.harvard.edu/manifests/drs:103...
# 4  https://iiif.lib.harvard.edu/manifests/drs:108...
#
#                                    bibl H-ID  \
# 0                              352571|737330
# 1                              736662|736663
# 2         354463|351329|741031|741991|742134
# 3                              741003|742210
# 4  356441|357556|349972|742148|742106|742300
#
#                                    bibl Record Title  \
# 0  De Ricci et Wilson 1935-1937, II, p. 2212|Dunn...
# 1     Wouters 1962, no. 95|Cat. Monnikenwerk, no. 30
# 2  1983, Cambridge (Mass), p. 34 n° 16, fig.|Bond...
# 3     Boston 2016, p. 294 n° 234|Mariani Canova 1975
# 4  Light 1995, p. 23-29, pl. 31|1983, Cambridge (...
#
#   external link (Web site / page) H-ID  \
# 0                               325568
# 1                               735403
# 2                               741340
# 3                               741328
# 4                               741221
#
#         external link (Web site / page) Record Title  Country
# 0  McGill Digital Library, http://digital.library...  Belgium
# 1  MMDC, http://www.mmdc.nl/static/site/search/de...  Belgium
# 2  Digital Scriptorium, http://ds.lib.berkeley.ed...   France
# 3  Digital Scriptorium, http://ds.lib.berkeley.ed...    Italy
# 4  Digital Scriptorium, http://ds.lib.berkeley.ed...   France

# %%
df['leaf dimensions : height (mm)'] = pd.to_numeric(df['leaf dimensions : height (mm)'], errors='coerce')
df['origDate'] = pd.to_numeric(df['origDate'], errors='coerce')
# %%
# Define a function to calculate the "origDate-avg"
def calculate_origDate_avg(row):
    if not pd.isna(row['origDate']):
        return row['origDate']
    elif not pd.isna(row['origDate : from']) and not pd.isna(row['origDate : to']):
        return (row['origDate : from'] + row['origDate : to']) / 2
    else:
        return np.nan

# Apply the function to create the new column
df['origDate-avg'] = df.apply(calculate_origDate_avg, axis=1)
# df['origDate-avg'] = df['origDate-avg'].round().astype(int)

# %%
df.head()
# Out:
#    Manuscript H-ID  repository_key (Organisation) H-ID  \
# 0              433                              739889
# 1           734419                              740297
# 2             6513                              740138
# 3             6494                              740138
# 4             6456                              740138
#
#           repository_key (Organisation) Record Title         idno  \
# 0  Montréal, McGill University Library (Organisat...          101
# 1  Maastricht, Regionaal Historisch Centrum Limbu...       ms. 48
# 2  Cambridge (MA), Harvard University, Houghton L...  MS Typ 0464
# 3  Cambridge (MA), Harvard University, Houghton L...  MS Typ 1000
# 4  Cambridge (MA), Harvard University, Houghton L...   MS Lat 017
#
#   altIdentifier     idMedium msItem H-ID  \
# 0           NaN  100086833.0      737250
# 1           NaN          NaN      735336
# 2           NaN          NaN      715768
# 3           NaN          NaN      715765
# 4           NaN          NaN      715762
#
#                                          rec_Title_2 Work H-ID  \
# 0  Montréal, McGill University Library, 101 : Hou...     75966
# 1  Maastricht, Regionaal Historisch Centrum Limbu...     75966
# 2  Cambridge (MA), Harvard University, Houghton L...     75966
# 3  Cambridge (MA), Harvard University, Houghton L...     75966
# 4  Cambridge (MA), Harvard University, Houghton L...     75966
#
#                     Work Record Title number of volume    support  \
# 0  Hours of the Virgin | L1 | Section              NaN  parchment
# 1  Hours of the Virgin | L1 | Section              NaN  parchment
# 2  Hours of the Virgin | L1 | Section              NaN  parchment
# 3  Hours of the Virgin | L1 | Section              NaN  parchment
# 4  Hours of the Virgin | L1 | Section              NaN  parchment
#
#                                               extent  \
# 0                              053 ff. (CCLL)|53 ff.
# 1                         105 ff. (paginated: 1-204)
# 2                             147 ff. (CCLL)|ff. 147
# 3  ff.162 ( numbered ff. 171, lacking ff. 144, 14...
# 4                                     141 ff. (CCLL)
#
#    leaf dimensions : height (mm) leaf dimensions : width (mm)  \
# 0                            NaN                          NaN
# 1                          177.0                          131
# 2                          116.0                           88
# 3                           83.0                           57
# 4                          200.0                          132
#
#   justification : height (mm) justification : width (mm)  columns  \
# 0                          98                         60      1.0
# 1                         101                         70      1.0
# 2                          64                         45      1.0
# 3                          54                         36      NaN
# 4                         NaN                        NaN      1.0
#
#    writtenLines   script type formality  origDate  origDate : from  \
# 0           NaN           NaN       NaN       NaN              NaN
# 1          17.0     Textualis       NaN       NaN           1451.0
# 2           NaN       Cursiva       NaN       NaN           1480.0
# 3           NaN  Humanistique       NaN       NaN           1501.0
# 4           NaN       Hybrida       NaN       NaN           1476.0
#
#    origDate : to    origDate : proposed date  \
# 0            NaN                         NaN
# 1         1475.0  third quarter 15th century
# 2         1500.0                  c. 1475-80
# 3         1550.0                  c. 1500-10
# 4         1500.0                         NaN
#
#   origPlace (relationship marker) H-ID  \
# 0                                37509
# 1                                37669
# 2                                38142
# 3                                38068
# 4                                37638
#
#   origPlace (relationship marker) Record Title origPlace : proposed origin  \
# 0                               Brugge (Place)                      Bruges
# 1                              Hainaut (Place)                         NaN
# 2                              Bourges (Place)             Bourges, France
# 3                              Venezia (Place)               Venice, Italy
# 4                               France (Place)                         NaN
#
#                                        iiif manifest  \
# 0                                                NaN
# 1                                                NaN
# 2  https://iiif.lib.harvard.edu/manifests/drs:497...
# 3  https://iiif.lib.harvard.edu/manifests/drs:103...
# 4  https://iiif.lib.harvard.edu/manifests/drs:108...
#
#                                    bibl H-ID  \
# 0                              352571|737330
# 1                              736662|736663
# 2         354463|351329|741031|741991|742134
# 3                              741003|742210
# 4  356441|357556|349972|742148|742106|742300
#
#                                    bibl Record Title  \
# 0  De Ricci et Wilson 1935-1937, II, p. 2212|Dunn...
# 1     Wouters 1962, no. 95|Cat. Monnikenwerk, no. 30
# 2  1983, Cambridge (Mass), p. 34 n° 16, fig.|Bond...
# 3     Boston 2016, p. 294 n° 234|Mariani Canova 1975
# 4  Light 1995, p. 23-29, pl. 31|1983, Cambridge (...
#
#   external link (Web site / page) H-ID  \
# 0                               325568
# 1                               735403
# 2                               741340
# 3                               741328
# 4                               741221
#
#         external link (Web site / page) Record Title  Country  origDate-avg
# 0  McGill Digital Library, http://digital.library...  Belgium           NaN
# 1  MMDC, http://www.mmdc.nl/static/site/search/de...  Belgium        1463.0
# 2  Digital Scriptorium, http://ds.lib.berkeley.ed...   France        1490.0
# 3  Digital Scriptorium, http://ds.lib.berkeley.ed...    Italy        1525.5
# 4  Digital Scriptorium, http://ds.lib.berkeley.ed...   France        1488.0

# %% [markdown]
# Convert data to numeric if needed. Reduce scope.

# %%
# Drop rows with NaN, 0, or blank values in columns A and C
df = df.dropna(subset=['leaf dimensions : height (mm)'])
df = df[df['leaf dimensions : height (mm)'] != 0]

df.shape
# Out:
# (6560, 35)

# %%
def process_country(value):
    countries = [country.strip() for country in value.split('|') if country.strip()]
    
    # Check if all values are the same
    if len(set(countries)) == 1:
        return countries[0]
    else:
        # If multiple values, return sorted and unique values
        # return '|'.join(sorted(set(countries)))
        return 'multiple countries'

# Apply the function to create the new "Processed_Country" column
df['Processed_Country'] = df['Country'].apply(process_country)

# %% [markdown]
# # Categories and pivot tables

# %% [markdown]
# ## Dimensions / Country

# %%
# Assuming 'df' is your DataFrame
pivot_table_avg_dimensions_by_Country = df.pivot_table(values='leaf dimensions : height (mm)', index='Processed_Country', aggfunc='mean').round(1)

# Display the pivot table
print(pivot_table_avg_dimensions_by_Country)
# Out:
#                     leaf dimensions : height (mm)
# Processed_Country
# Austria                                     130.2
# Belgium                                     162.2
# Czech Republic                              161.2
# France                                      173.2
# Germany                                     128.3
# Italy                                       133.3
# Lithuania                                   150.0
# Netherlands                                 156.1
# Poland                                      109.5
# Portugal                                    120.0
# Romania                                     160.0
# Spain                                       163.8
# Sweden                                      145.4
# Switzerland                                 172.4
# UK                                          174.7
# multiple countries                          171.5
# nan                                         162.3

# %% [markdown]
# ## Dimensions by DateRange (span of 50 years)

# %%
# Convert 'origDate-avg' to numeric, coercing errors to NaN
df['origDate-avg'] = pd.to_numeric(df['origDate-avg'], errors='coerce')

# Create a new column for the date range categories
bins = range(1001, 2001, 50)
labels = [f"{start}-{start+49}" for start in bins[:-1]]
df['DateRange'] = pd.cut(df['origDate-avg'], bins=bins, labels=labels, right=False)

# %%
pivot_table_avg_dimensions_by_DateRange = df.pivot_table(values='leaf dimensions : height (mm)', index='DateRange', aggfunc='mean').round(1)

# Display the pivot table
print(pivot_table_avg_dimensions_by_DateRange)
# Out:
#            leaf dimensions : height (mm)
# DateRange
# 1001-1050                          350.0
# 1101-1150                          167.5
# 1151-1200                          223.1
# 1201-1250                          214.4
# 1251-1300                          176.6
# 1301-1350                          156.2
# 1351-1400                          160.1
# 1401-1450                          165.2
# 1451-1500                          161.1
# 1501-1550                          162.0
# 1551-1600                          175.5
# 1601-1650                          150.1
# 1651-1700                          236.0
# 1701-1750                          129.0
# 1801-1850                          124.6
# 1901-1950                          193.0

# %%
# Pivot table for average dimensions by DateRange and Country
pivot_table_avg_dimensions = df.pivot_table(
    values='leaf dimensions : height (mm)',
    index=['DateRange', 'Processed_Country'],
    aggfunc='mean',
    margins=True,  # Add subtotals
    margins_name='missing',  # Specify the name for the subtotal row
).round(1)

# %%
pivot_table_avg_dimensions
# Out:
#                               leaf dimensions : height (mm)
# DateRange Processed_Country
# 1001-1050 nan                                         350.0
# 1101-1150 France                                      175.0
#           Germany                                     160.0
# 1151-1200 France                                      228.0
#           Germany                                     189.0
#           nan                                         227.3
# 1201-1250 Belgium                                     180.2
#           France                                      195.0
#           Germany                                     250.0
#           UK                                          227.2
#           multiple countries                          167.0
#           nan                                         220.6
# 1251-1300 Belgium                                     159.2
#           France                                      207.4
#           Germany                                     119.0
#           Italy                                       124.3
#           Netherlands                                 167.5
#           Switzerland                                 335.0
#           UK                                          158.0
#           multiple countries                          186.0
#           nan                                         171.2
# 1301-1350 Belgium                                     138.0
#           Czech Republic                              245.0
#           France                                      154.2
#           Germany                                     117.5
#           Italy                                       149.0
#           Netherlands                                 149.0
#           Spain                                       160.0
#           UK                                          219.5
#           nan                                         155.9
# 1351-1400 Austria                                     141.0
#           Belgium                                     139.7
#           France                                      162.1
#           Germany                                     122.0
#           Italy                                       156.4
#           Netherlands                                 161.2
#           UK                                          195.9
#           multiple countries                          172.5
#           nan                                         158.2
# 1401-1450 Austria                                     140.0
#           Belgium                                     166.2
#           Czech Republic                              127.5
#           France                                      175.5
#           Germany                                     128.7
#           Italy                                       123.6
#           Lithuania                                   140.0
#           Netherlands                                 148.7
#           Spain                                       160.0
#           Sweden                                      135.0
#           Switzerland                                 100.0
#           UK                                          157.3
#           multiple countries                          182.0
#           nan                                         165.3
# 1451-1500 Austria                                     120.0
#           Belgium                                     160.6
#           Czech Republic                              180.0
#           France                                      170.9
#           Germany                                     117.1
#           Italy                                       132.7
#           Lithuania                                   152.5
#           Netherlands                                 159.7
#           Poland                                       86.0
#           Spain                                       163.0
#           Sweden                                      175.0
#           Switzerland                                 166.8
#           UK                                          210.7
#           multiple countries                          162.1
#           nan                                         159.5
# 1501-1550 Belgium                                     163.3
#           Czech Republic                              130.0
#           France                                      174.9
#           Germany                                     122.8
#           Italy                                       151.7
#           Netherlands                                 148.3
#           Poland                                      133.0
#           Portugal                                    142.0
#           Romania                                     160.0
#           Sweden                                      141.0
#           Switzerland                                 105.0
#           multiple countries                          177.4
#           nan                                         159.0
# 1551-1600 Belgium                                     142.7
#           France                                      182.2
#           Italy                                        95.5
#           nan                                         183.9
# 1601-1650 France                                      164.0
#           Germany                                     117.5
#           Italy                                       207.7
#           Spain                                       175.0
#           nan                                         131.8
# 1651-1700 France                                      297.0
#           nan                                         205.5
# 1701-1750 nan                                         129.0
# 1801-1850 UK                                          105.0
#           nan                                         137.7
# 1901-1950 nan                                         193.0
# missing                                               163.2

# %%
# Pivot table for average dimensions by DateRange and Country
pivot_table_avg_dimensions_full = df.pivot_table(
    values=['leaf dimensions : height (mm)', 'Manuscript H-ID'],
    index=['DateRange', 'Processed_Country'],
    aggfunc={'leaf dimensions : height (mm)': 'mean', 'Manuscript H-ID': 'count'},
    margins=True,  # Add subtotals
    margins_name='missing',  # Specify the name for the subtotal row
).round(1)

pivot_table_avg_dimensions_full.head()
# Out:
#                              Manuscript H-ID  leaf dimensions : height (mm)
# DateRange Processed_Country
# 1001-1050 Austria                          0                            NaN
#           Belgium                          0                            NaN
#           Czech Republic                   0                            NaN
#           France                           0                            NaN
#           Germany                          0                            NaN

# %% [markdown]
# # Correlation (khi2)

# %% [markdown]
# ## Date and Country

# %%
# Create a contingency table
contingency_table = pd.crosstab(df['Processed_Country'], df['DateRange'])

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-squared value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-squared value: 685.9016554073268
# P-value: 1.5445067941457784e-44

# %% [markdown]
# ## Size and Date

# %%
# Create a new column for the date range categories
bins = range(0, 900, 20)
labels = [f"{start}-{start+19}" for start in bins[:-1]]
df['heightRange'] = pd.cut(df['leaf dimensions : height (mm)'], bins=bins, labels=labels, right=False)


# Create a contingency table
contingency_table = pd.crosstab(df['heightRange'], df['DateRange'])

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-squared value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-squared value: 2125.7883044087607
# P-value: 7.846989457049216e-242

# %% [markdown]
# ## Country and Size

# %%
# Create a contingency table
contingency_table = pd.crosstab(df['heightRange'], df['Country'])

# Perform the chi-squared test
chi2, p, _, _ = chi2_contingency(contingency_table)

# Print the results
print(f"Chi-squared value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi-squared value: 2179.00411141994
# P-value: 4.857588947833162e-26
